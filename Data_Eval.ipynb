# %% [markdown]
# <a href="https://colab.research.google.com/github/thecodebloodedguy/career-guidance-ml-model/blob/main/Data_Eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/thecodebloodedguy/career-guidance-ml-model/main/dataset-github.csv")

# %%
df.shape
# Out:
# (20000, 25)

# %%
df.dropna()
# Out:
#         Operating Systems  Algorithms  Programming Concepts  \
# 0                      69          63                    78
# 1                      78          62                    73
# 2                      71          86                    91
# 3                      76          87                    60
# 4                      92          62                    90
# ...                   ...         ...                   ...
# 19995                  83          67                    62
# 19996                  80          69                    83
# 19997                  83          70                    80
# 19998                  68          87                    91
# 19999                  73          77                    74
#
#        Software Engineering  Computer Networks  Electronics Subjects  \
# 0                        87                 94                    94
# 1                        60                 71                    70
# ...

# %%
df
# Out:
#         Operating Systems  Algorithms  Programming Concepts  \
# 0                      69          63                    78
# 1                      78          62                    73
# 2                      71          86                    91
# 3                      76          87                    60
# 4                      92          62                    90
# ...                   ...         ...                   ...
# 19995                  83          67                    62
# 19996                  80          69                    83
# 19997                  83          70                    80
# 19998                  68          87                    91
# 19999                  73          77                    74
#
#        Software Engineering  Computer Networks  Electronics Subjects  \
# 0                        87                 94                    94
# 1                        60                 71                    70
# ...

# %%
df.isna().isna().sum()
# Out:
#  Operating Systems                    0
# Algorithms                            0
# Programming Concepts                  0
# Software Engineering                  0
# Computer Networks                     0
# Electronics Subjects                  0
# Computer Architecture                 0
# Mathematics                           0
#  Communication skills                 0
# Hours working per day                 0
# Logical quotient rating               0
# hackathons                            0
# coding skills rating                  0
# public speaking points                0
# can work long time before system?     0
# self-learning capability?             0
# certifications                        0
# workshops                             0
# Interested subjects                   0
# interested career area                0
# Job/Higher Studies?                   0
# Type of company want to settle in?    0
# Management or Technical               0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         Operating Systems  Algorithms  Programming Concepts  \
# 0                      69          63                    78
# 1                      78          62                    73
# 2                      71          86                    91
# 3                      76          87                    60
# 4                      92          62                    90
# ...                   ...         ...                   ...
# 19995                  83          67                    62
# 19996                  80          69                    83
# 19997                  83          70                    80
# 19998                  68          87                    91
# 19999                  73          77                    74
#
#        Software Engineering  Computer Networks  Electronics Subjects  \
# 0                        87                 94                    94
# 1                        60                 71                    70
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Length: 20000, dtype: bool

# %%
df.drop_duplicates()
# Out:
#         Operating Systems  Algorithms  Programming Concepts  \
# 0                      69          63                    78
# 1                      78          62                    73
# 2                      71          86                    91
# 3                      76          87                    60
# 4                      92          62                    90
# ...                   ...         ...                   ...
# 19995                  83          67                    62
# 19996                  80          69                    83
# 19997                  83          70                    80
# 19998                  68          87                    91
# 19999                  73          77                    74
#
#        Software Engineering  Computer Networks  Electronics Subjects  \
# 0                        87                 94                    94
# 1                        60                 71                    70
# ...

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].astype('category')
    df[col] = df[col].cat.codes

# %%
df
# Out:
#         Operating Systems  Algorithms  Programming Concepts  \
# 0                      69          63                    78
# 1                      78          62                    73
# 2                      71          86                    91
# 3                      76          87                    60
# 4                      92          62                    90
# ...                   ...         ...                   ...
# 19995                  83          67                    62
# 19996                  80          69                    83
# 19997                  83          70                    80
# 19998                  68          87                    91
# 19999                  73          77                    74
#
#        Software Engineering  Computer Networks  Electronics Subjects  \
# 0                        87                 94                    94
# 1                        60                 71                    70
# ...

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of         Operating Systems  Algorithms  Programming Concepts  \
# 0                      69          63                    78
# 1                      78          62                    73
# 2                      71          86                    91
# 3                      76          87                    60
# 4                      92          62                    90
# ...                   ...         ...                   ...
# 19995                  83          67                    62
# 19996                  80          69                    83
# 19997                  83          70                    80
# 19998                  68          87                    91
# 19999                  73          77                    74
#
#        Software Engineering  Computer Networks  Electronics Subjects  \
# 0                        87                 94                    94
# 1                        60                 71                    70
# ...

# %%
suggest=df.groupby('Suggested Job Role')

# %%
suggest.mean()
# Out:
#                      Operating Systems  Algorithms  Programming Concepts  \
# Suggested Job Role
# 0                            76.524501   77.061706             76.934664
# 1                            76.742593   78.055556             76.646296
# 2                            76.963918   77.154639             77.092784
# 3                            76.818493   76.957192             77.073630
# 4                            76.798942   76.733686             78.291005
# 5                            76.829787   76.900709             77.962766
# 6                            77.084317   76.500843             77.215852
# 7                            76.879518   76.913941             77.013769
# 8                            76.942105   77.289474             77.215789
# 9                            77.232993   76.763605             76.969388
# 10                           76.970696   76.835165             76.917582
# 11                           77.331492   76.918969             77.613260
# ...

# %%
import seaborn as sb
sb.set(style="darkgrid")
g = sb.catplot(x="Suggested Job Role",col="Job/Higher Studies?",
                data=df, kind="count" );
